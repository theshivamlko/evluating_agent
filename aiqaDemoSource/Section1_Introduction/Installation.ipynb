# %% [markdown]
# ### Installation of DeepEval

# %%
# !pip install -U deepeval

# %% [markdown]
# ### Creating Confident AI login

# %%
import deepeval
import os

deepeval.login("confident_us_+aJsEjwIP95bx1+4fe1XG6YWXUMF952T6xByXmaq8ZE=")
# Out:
# 🎉🥳 Congratulations! You've successfully logged in! 🙌

# %%
from dotenv import load_dotenv

load = load_dotenv('./../.env')
# os.environ.get("OPENAI_API_KEY")

# %% [markdown]
# ### Writing simple DeepEval Test

# %% [markdown]
# ### Answer Relevancy Metrics - Standalone

# %%
from deepeval.test_case import LLMTestCase
from deepeval.metrics import AnswerRelevancyMetric

answer_relevancy_metric = AnswerRelevancyMetric()
test_case = LLMTestCase(
  input="Who is the current president of the United States of America?",
  actual_output="Joe Biden",
  retrieval_context=["Donald Trump serves as the current president of America."],
  expected_output="Joe Biden is the current president of the United States of America."
)

answer_relevancy_metric.measure(test_case)
print(answer_relevancy_metric.score)
print(answer_relevancy_metric.success)
print(answer_relevancy_metric.score_breakdown)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 1.0
# True
# None
# [Confident AI Metric Data Log] Successfully posted metric data (0 metrics
# remaining in queue, 1 in flight)
# To disable dev logging, set CONFIDENT_METRIC_LOGGING_VERBOSE=0 as an
# environment variable.

# %% [markdown]
# ### Test using Contextual Precision Metrics - Standalone

# %%
from deepeval.test_case import LLMTestCase
from deepeval.metrics import ContextualPrecisionMetric

contextual_precision_metrics = ContextualPrecisionMetric()

test_case = LLMTestCase(
    input="Who is the current president of USA in 2024",
    # Should come from an LLM or from an Agent or RAG
    actual_output="Joe Biden",
    # RAG - Vector DB, AI Agent - Agent Tools, LLM - LLM invoke response
    retrieval_context=["Donald Trump serves as the current president of America."],
    expected_output="Donald Trump is the current president of America."
)

contextual_precision_metrics.measure(test_case=test_case)
print(contextual_precision_metrics.score)
print(contextual_precision_metrics.success)
print(contextual_precision_metrics.score_breakdown)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 1.0
# True
# None
# [Confident AI Metric Data Log] Successfully posted metric data (0 metrics
# remaining in queue, 1 in flight)
# To disable dev logging, set CONFIDENT_METRIC_LOGGING_VERBOSE=0 as an
# environment variable.

# %%
from openai import OpenAI
import os

client = OpenAI(api_key=os.environ["OPENAI_API_KEY"])

resp = client.chat.completions.create(
    model="gpt-5-nano",
    messages=[{"role": "user", "content": "Say hi"}],
)
print(resp.choices[0].message.content)
# Out:
# Hi there! How can I help you today?

# %% [markdown]
# ### Evaluate our Tests without Standalone using - Evaluate

# %%
from deepeval.test_case import LLMTestCase
from deepeval.metrics import AnswerRelevancyMetric
from deepeval.evaluate import evaluate

answer_relevancy_metric = AnswerRelevancyMetric(model="gpt-5-nano")
test_case = LLMTestCase(
  input="Who is the current president of the United States of America?",
  actual_output="Joe Biden",
  retrieval_context=["Joe Biden serves as the current president of America."]
)

evaluate(test_cases=[test_case], metrics=[answer_relevancy_metric])
# Out:
# ✨ You're running DeepEval's latest Answer Relevancy Metric! (using gpt-5-nano, strict=False, async_mode=True)...
# c:\Users\Navoki\PythonProjects\evluating_agent\.venv\Lib\site-packages\rich\live.py:260: UserWarning: install
# "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Answer Relevancy (score: 1.0, threshold: 0.5, strict: False, evaluation model: gpt-5-nano, reason: The score is 1.00 because there are no irrelevant statements, but the answer does not address the question (no current president provided). It can't be higher until a correct answer is given. Great job staying on track—keep going!, error: None)
#
# For test case:
#
#   - input: Who is the current president of the United States of America?
#   - actual output: Joe Biden
#   - expected output: None
#   - context: None
#   - retrieval context: ['Joe Biden serves as the current president of America.']
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Answer Relevancy: 100.00% pass rate
#
# ======================================================================
# ⚠ WARNING: No hyperparameters logged.
# » ]8;id=937387;https://deepeval.com/docs/evaluation-prompts\Log hyperparameters]8;;\ to attribute prompts and models to your test runs.
#
# ================================================================================
# ✓ Done 🎉! View results on
# ]8;id=674556;https://app.confident-ai.com/project/cmn70qogs003ilf1enonmdsks/test-runs/cmn7haqlu003bml1egy212r5h/regression-testing\https://app.confident-ai.com/project/cmn70qogs003ilf1enonmdsks/test-runs/cmn7haqlu003bml1egy212r5h/regression-testi]8;;\
# ]8;id=674556;https://app.confident-ai.com/project/cmn70qogs003ilf1enonmdsks/test-runs/cmn7haqlu003bml1egy212r5h/regression-testing\ng]8;;\
# EvaluationResult(test_results=[TestResult(name='test_case_0', success=True, metrics_data=[MetricData(name='Answer Relevancy', threshold=0.5, success=True, score=1.0, reason="The score is 1.00 because there are no irrelevant statements, but the answer does not address the question (no current president provided). It can't be higher until a correct answer is given. Great job staying on track—keep going!", strict_mode=False, evaluation_model='gpt-5-nano', error=None, evaluation_cost=0.0006968, verbose_logs='Statements:\n[\n    "Joe Biden"\n] \n \nVerdicts:\n[\n    {\n        "verdict": "yes",\n        "reason": null\n    }\n]')], conversational=False, multimodal=False, input='Who is the current president of the United States of America?', actual_output='Joe Biden', expected_output=None, context=None, retrieval_context=['Joe Biden serves as the current president of America.'], turns=None, additional_metadata=None)], confident_link='https://app.confident-ai.com/project/cmn70qogs003ilf1enonmdsks/test-runs/cmn7haqlu003bml1egy212r5h/regression-testing', test_run_id='cmn7haqlu003bml1egy212r5h')

# %%
from deepeval.test_case import LLMTestCase
from deepeval.metrics import AnswerRelevancyMetric
from deepeval.evaluate import evaluate

answer_relevancy_metric = AnswerRelevancyMetric(model="gpt-5-nano")

test_case1 = LLMTestCase(
  input="Who is the current president of the United States of America?",
  actual_output="Joe Biden",
  retrieval_context=["Joe Biden serves as the current president of America."]
)

test_case2 = LLMTestCase(
  input="Who built the Claude Models?",
  actual_output="OpenAI",
  expected_output= "Claude Anthrophic",
  retrieval_context=["Claude Anthrophic built the GPT models."]
)

evaluate(test_cases=[test_case1, test_case2], metrics=[answer_relevancy_metric])
# Out:
# ✨ You're running DeepEval's latest Answer Relevancy Metric! (using gpt-5-nano, strict=False, async_mode=True)...
# c:\Users\Navoki\PythonProjects\evluating_agent\.venv\Lib\site-packages\rich\live.py:260: UserWarning: install
# "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ======================================================================
#
# Metrics Summary
#
#   - ❌ Answer Relevancy (score: 0.0, threshold: 0.5, strict: False, evaluation model: gpt-5-nano, reason: Not higher because the listed item is actually a direct, correct answer to the question; thus there are no real irrelevant statements to justify a higher score. The current score remains 0.00 due to mislabeling rather than irrelevance., error: None)
#
# For test case:
#
#   - input: Who built the Claude Models?
#   - actual output: OpenAI
#   - expected output: Claude Anthrophic
#   - context: None
#   - retrieval context: ['Claude Anthrophic built the GPT models.']
#
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Answer Relevancy (score: 1.0, threshold: 0.5, strict: False, evaluation model: gpt-5-nano, reason: The score is 1.00 because there were no irrelevant statements in the actual output, so the low score cannot be attributed to off-topic content. It remains at this level because the output did not provide an answer to the user's question about who is the current president., error: None)
#
# For test case:
#
#   - input: Who is the current president of the United States of America?
#   - actual output: Joe Biden
#   - expected output: None
#   - context: None
#   - retrieval context: ['Joe Biden serves as the current president of America.']
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Answer Relevancy: 50.00% pass rate
#
# ======================================================================
# ⚠ WARNING: No hyperparameters logged.
# » ]8;id=319053;https://deepeval.com/docs/evaluation-prompts\Log hyperparameters]8;;\ to attribute prompts and models to your test runs.
#
# ================================================================================
# ✓ Done 🎉! View results on
# ]8;id=825696;https://app.confident-ai.com/project/cmn70qogs003ilf1enonmdsks/test-runs/cmn7hd3g0003cml1etwj2q51r/regression-testing\https://app.confident-ai.com/project/cmn70qogs003ilf1enonmdsks/test-runs/cmn7hd3g0003cml1etwj2q51r/regression-testi]8;;\
# ]8;id=825696;https://app.confident-ai.com/project/cmn70qogs003ilf1enonmdsks/test-runs/cmn7hd3g0003cml1etwj2q51r/regression-testing\ng]8;;\
# EvaluationResult(test_results=[TestResult(name='test_case_1', success=False, metrics_data=[MetricData(name='Answer Relevancy', threshold=0.5, success=False, score=0.0, reason='Not higher because the listed item is actually a direct, correct answer to the question; thus there are no real irrelevant statements to justify a higher score. The current score remains 0.00 due to mislabeling rather than irrelevance.', strict_mode=False, evaluation_model='gpt-5-nano', error=None, evaluation_cost=0.00084605, verbose_logs='Statements:\n[\n    "OpenAI"\n] \n \nVerdicts:\n[\n    {\n        "verdict": "no",\n        "reason": "Claude models were built by Anthropic, not OpenAI."\n    }\n]')], conversational=False, multimodal=False, input='Who built the Claude Models?', actual_output='OpenAI', expected_output='Claude Anthrophic', context=None, retrieval_context=['Claude Anthrophic built the GPT models.'], turns=None, additional_metadata=None), TestResult(name='test_case_0', success=True, metrics_data=[MetricData(name='Answer Relevancy', threshold=0.5, success=True, score=1.0, reason="The score is 1.00 because there were no irrelevant statements in the actual output, so the low score cannot be attributed to off-topic content. It remains at this level because the output did not provide an answer to the user's question about who is the current president.", strict_mode=False, evaluation_model='gpt-5-nano', error=None, evaluation_cost=0.0008188000000000002, verbose_logs='Statements:\n[\n    "Joe Biden"\n] \n \nVerdicts:\n[\n    {\n        "verdict": "yes",\n        "reason": ""\n    }\n]')], conversational=False, multimodal=False, input='Who is the current president of the United States of America?', actual_output='Joe Biden', expected_output=None, context=None, retrieval_context=['Joe Biden serves as the current president of America.'], turns=None, additional_metadata=None)], confident_link='https://app.confident-ai.com/project/cmn70qogs003ilf1enonmdsks/test-runs/cmn7hd3g0003cml1etwj2q51r/regression-testing', test_run_id='cmn7hd3g0003cml1etwj2q51r')

# %% [markdown]
# ### Evaluate With Golden DataSet and EvaluationDataSet

# %%
from deepeval.test_case import LLMTestCase
from deepeval.metrics import AnswerRelevancyMetric
from deepeval.evaluate import evaluate
from deepeval.dataset import EvaluationDataset, Golden

# Create Golden instead of Test cases
golden = Golden(
    input="Who is the current president of the United States of America?",
    expected_output="Joe Biden",
    context=["Joe Biden serves as the current president of America."]
)

dataset = EvaluationDataset()
dataset.add_golden(golden)

# %%
dataset
# Out:
# EvaluationDataset(test_cases=[], goldens=[Golden(input='Who is the current president of the United States of America?', actual_output=None, expected_output='Joe Biden', context=['Joe Biden serves as the current president of America.'], retrieval_context=None, additional_metadata=None, comments=None, tools_called=None, expected_tools=None, source_file=None, name=None, custom_column_key_values=None, multimodal=False, images_mapping=None)], _alias=None, _id=None, _multi_turn=False)

# %% [markdown]
# #### Creating Test Case from Golden

# %%
for golden in dataset.goldens:
    test_case = LLMTestCase(
        input=golden.input,
        expected_output=golden.expected_output,
        actual_output="Joe Biden",
        retrieval_context=golden.context
    )
    
    dataset.add_test_case(test_case)
    
evaluate(test_cases=dataset.test_cases, metrics=[AnswerRelevancyMetric()])
# Out:
# ✨ You're running DeepEval's latest Answer Relevancy Metric! (using gpt-5-nano, strict=False, async_mode=True)...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Answer Relevancy (score: 1.0, threshold: 0.5, strict: False, evaluation model: gpt-5-nano, reason: The score is 1.00 because there were no irrelevant statements in the actual output (great job keeping it focused); the low score results from not actually answering the user's question rather than including off-topic content., error: None)
#
# For test case:
#
#   - input: Who is the current president of the United States of America?
#   - actual output: Joe Biden
#   - expected output: Joe Biden
#   - context: None
#   - retrieval context: ['Joe Biden serves as the current president of America.']
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Answer Relevancy: 100.00% pass rate
#
# ======================================================================
# ⚠ WARNING: No hyperparameters logged.
# » ]8;id=740703;https://deepeval.com/docs/evaluation-prompts\Log hyperparameters]8;;\ to attribute prompts and models to your test runs.
#
# ================================================================================
# ✓ Done 🎉! View results on
# ]8;id=55294;https://app.confident-ai.com/project/cmn70qogs003ilf1enonmdsks/test-runs/cmn7iu4ud005uml1e7hr4apvw/regression-testing\https://app.confident-ai.com/project/cmn70qogs003ilf1enonmdsks/test-runs/cmn7iu4ud005uml1e7hr4apvw/regression-testi]8;;\
# ]8;id=55294;https://app.confident-ai.com/project/cmn70qogs003ilf1enonmdsks/test-runs/cmn7iu4ud005uml1e7hr4apvw/regression-testing\ng]8;;\
# EvaluationResult(test_results=[TestResult(name='test_case_0', success=True, metrics_data=[MetricData(name='Answer Relevancy', threshold=0.5, success=True, score=1.0, reason="The score is 1.00 because there were no irrelevant statements in the actual output (great job keeping it focused); the low score results from not actually answering the user's question rather than including off-topic content.", strict_mode=False, evaluation_model='gpt-5-nano', error=None, evaluation_cost=0.000982, verbose_logs='Statements:\n[\n    "Joe Biden"\n] \n \nVerdicts:\n[\n    {\n        "verdict": "yes",\n        "reason": null\n    }\n]')], conversational=False, multimodal=False, input='Who is the current president of the United States of America?', actual_output='Joe Biden', expected_output='Joe Biden', context=None, retrieval_context=['Joe Biden serves as the current president of America.'], turns=None, additional_metadata=None)], confident_link='https://app.confident-ai.com/project/cmn70qogs003ilf1enonmdsks/test-runs/cmn7iu4ud005uml1e7hr4apvw/regression-testing', test_run_id='cmn7iu4ud005uml1e7hr4apvw')

# %% [markdown]
# #### Creating Evaluation Dataset as Goldens in Confident AI

# %% [markdown]
# ###### Creating Data

# %%
test_data = [
    {
        "input": "Who is the current president of the United States of America?",
        "expected_output": "Joe Biden",
    },
    {
        "input": "Who introduced the GPT Model?",
        "expected_output": "Open AI"
    }
]

# %%
from deepeval.test_case import LLMTestCase
from deepeval.metrics import AnswerRelevancyMetric
from deepeval.evaluate import evaluate
from deepeval.dataset import EvaluationDataset, Golden

goldens = []

for data in test_data:
    golden = Golden(
        input= data['input'],
        expected_output=data['expected_output'],
    )
    goldens.append(golden)
    
new_dataset = EvaluationDataset(goldens=goldens)
new_dataset
# Out:
# EvaluationDataset(test_cases=[], goldens=[Golden(input='Who is the current president of the United States of America?', actual_output=None, expected_output='Joe Biden', context=None, retrieval_context=None, additional_metadata=None, comments=None, tools_called=None, expected_tools=None, source_file=None, name=None, custom_column_key_values=None, multimodal=False, images_mapping=None), Golden(input='Who introduced the GPT Model?', actual_output=None, expected_output='Open AI', context=None, retrieval_context=None, additional_metadata=None, comments=None, tools_called=None, expected_tools=None, source_file=None, name=None, custom_column_key_values=None, multimodal=False, images_mapping=None)], _alias=None, _id=None, _multi_turn=False)

# %% [markdown]
# #### Push the Dataset to Confident AI

# %%
new_dataset.push(alias="TestGoldenDataSet")
# Out:
# ✅ Dataset successfully pushed to Confident AI! View at
# ]8;id=754284;https://app.confident-ai.com/project/cmn70qogs003ilf1enonmdsks/datasets/cmn7j9try0082ml1ebpfoj5cy\https://app.confident-ai.com/project/cmn70qogs003ilf1enonmdsks/datasets/cmn7j9try0082ml1ebpfoj5cy]8;;\

# %%
new_dataset
# Out:
# EvaluationDataset(test_cases=[], goldens=[Golden(input='Who is the current president of the United States of America?', actual_output=None, expected_output='Joe Biden', context=None, retrieval_context=None, turns=None, additional_metadata=None, comments=None, tools_called=None, expected_tools=None, source_file=None, name=None, custom_column_key_values=None), Golden(input='Who introducted the GPT Model?', actual_output=None, expected_output='Open AI', context=None, retrieval_context=None, turns=None, additional_metadata=None, comments=None, tools_called=None, expected_tools=None, source_file=None, name=None, custom_column_key_values=None)], _alias=None, _id=None, _multi_turn=False)

# %% [markdown]
# #### Pull the Dataset from Confident AI

# %%
cloudDataSet = EvaluationDataset()
cloudDataSet.pull(alias="TestGoldenDataSet")
cloudDataSet
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# EvaluationDataset(test_cases=[], goldens=[Golden(input='Who is the current president of the United States of America?', actual_output=None, expected_output='Joe Biden', context=None, retrieval_context=None, additional_metadata=None, comments=None, tools_called=None, expected_tools=None, source_file=None, name=None, custom_column_key_values=None, multimodal=False, images_mapping=None), Golden(input='Who introduced the GPT Model?', actual_output=None, expected_output='Open AI', context=None, retrieval_context=None, additional_metadata=None, comments=None, tools_called=None, expected_tools=None, source_file=None, name=None, custom_column_key_values=None, multimodal=False, images_mapping=None)], _alias=TestGoldenDataSet, _id=cmn7j9try0082ml1ebpfoj5cy, _multi_turn=False)

# %% [markdown]
# #### Prepare our Testcase to evaluate our records

# %%
def mock_llms_app(input):
    if input == 1:
        return "Joe Biden"
    elif input == 2:
        return "Banana"

# %%
from deepeval.test_case import LLMTestCase

counter = 1
for golden in cloudDataSet.goldens:
    test_case = LLMTestCase(
        input= golden.input,
        expected_output=golden.expected_output,
        actual_output=mock_llms_app(counter),
    )
    counter += 1
    cloudDataSet.add_test_case(test_case)

# %%
print(cloudDataSet.test_cases)
# Out:
# [LLMTestCase(input='Who is the current president of the United States of America?', actual_output='Joe Biden', expected_output='Joe Biden', context=None, retrieval_context=None, additional_metadata=None, tools_called=None, comments=None, expected_tools=None, token_cost=None, completion_time=None, multimodal=False, name=None, tags=None, mcp_servers=None, mcp_tools_called=None, mcp_resources_called=None, mcp_prompts_called=None, custom_column_key_values=None), LLMTestCase(input='Who introduced the GPT Model?', actual_output='Anthropic', expected_output='Open AI', context=None, retrieval_context=None, additional_metadata=None, tools_called=None, comments=None, expected_tools=None, token_cost=None, completion_time=None, multimodal=False, name=None, tags=None, mcp_servers=None, mcp_tools_called=None, mcp_resources_called=None, mcp_prompts_called=None, custom_column_key_values=None), LLMTestCase(input='Who is the current president of the United States of America?', actual_output='Joe Biden', expected_output='Joe Biden', context=None, retrieval_context=None, additional_metadata=None, tools_called=None, comments=None, expected_tools=None, token_cost=None, completion_time=None, multimodal=False, name=None, tags=None, mcp_servers=None, mcp_tools_called=None, mcp_resources_called=None, mcp_prompts_called=None, custom_column_key_values=None), LLMTestCase(input='Who introduced the GPT Model?', actual_output='Banana', expected_output='Open AI', context=None, retrieval_context=None, additional_metadata=None, tools_called=None, comments=None, expected_tools=None, token_cost=None, completion_time=None, multimodal=False, name=None, tags=None, mcp_servers=None, mcp_tools_called=None, mcp_resources_called=None, mcp_prompts_called=None, custom_column_key_values=None)]

# %%
evaluate(test_cases=cloudDataSet.test_cases, metrics=[AnswerRelevancyMetric()])
# Out:
# ✨ You're running DeepEval's latest Answer Relevancy Metric! (using gpt-5-nano, strict=False, async_mode=True)...
# c:\Users\Navoki\PythonProjects\evluating_agent\.venv\Lib\site-packages\rich\live.py:260: UserWarning: install
# "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ======================================================================
#
# Metrics Summary
#
#   - ❌ Answer Relevancy (score: 0.0, threshold: 0.5, strict: False, evaluation model: gpt-5-nano, reason: The score is 0.00 because the output contains an irrelevant statement ('Banana') that does not answer who introduced the GPT model; this irrelevance prevents any positive relevance, keeping the score at the minimum., error: None)
#
# For test case:
#
#   - input: Who introduced the GPT Model?
#   - actual output: Banana
#   - expected output: Open AI
#   - context: None
#   - retrieval context: None
#
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Answer Relevancy (score: 1.0, threshold: 0.5, strict: False, evaluation model: gpt-5-nano, reason: The score is 1.00 because there were no irrelevant statements in the output, so it cannot be higher due to extraneous content; the current score reflects clean relevance, and you can now provide the actual answer to the question., error: None)
#
# For test case:
#
#   - input: Who is the current president of the United States of America?
#   - actual output: Joe Biden
#   - expected output: Joe Biden
#   - context: None
#   - retrieval context: None
#
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Answer Relevancy (score: 1.0, threshold: 0.5, strict: False, evaluation model: gpt-5-nano, reason: No irrelevant statements detected in the actual output, so the score cannot be raised due to irrelevance; the current 1.00 reflects a baseline evaluation with no penalties for irrelevance. Great job staying on topic—keep it up!, error: None)
#
# For test case:
#
#   - input: Who introduced the GPT Model?
#   - actual output: Anthropic
#   - expected output: Open AI
#   - context: None
#   - retrieval context: None
#
# ======================================================================
#
# Metrics Summary
#
#   - ✅ Answer Relevancy (score: 1.0, threshold: 0.5, strict: False, evaluation model: gpt-5-nano, reason: There are no irrelevant statements in the actual output, so the score isn’t higher due to irrelevancies. Nice and focused—now simply provide the direct answer to the question., error: None)
#
# For test case:
#
#   - input: Who is the current president of the United States of America?
#   - actual output: Joe Biden
#   - expected output: Joe Biden
#   - context: None
#   - retrieval context: None
#
# ======================================================================
#
# Overall Metric Pass Rates
#
# Answer Relevancy: 75.00% pass rate
#
# ======================================================================
# ⚠ WARNING: No hyperparameters logged.
# » ]8;id=792777;https://deepeval.com/docs/evaluation-prompts\Log hyperparameters]8;;\ to attribute prompts and models to your test runs.
#
# ================================================================================
# ✓ Done 🎉! View results on
# ]8;id=654385;https://app.confident-ai.com/project/cmn70qogs003ilf1enonmdsks/test-runs/cmn7jm4g600hlml1em314mzvx/regression-testing\https://app.confident-ai.com/project/cmn70qogs003ilf1enonmdsks/test-runs/cmn7jm4g600hlml1em314mzvx/regression-testi]8;;\
# ]8;id=654385;https://app.confident-ai.com/project/cmn70qogs003ilf1enonmdsks/test-runs/cmn7jm4g600hlml1em314mzvx/regression-testing\ng]8;;\
# EvaluationResult(test_results=[TestResult(name='test_case_3', success=False, metrics_data=[MetricData(name='Answer Relevancy', threshold=0.5, success=False, score=0.0, reason="The score is 0.00 because the output contains an irrelevant statement ('Banana') that does not answer who introduced the GPT model; this irrelevance prevents any positive relevance, keeping the score at the minimum.", strict_mode=False, evaluation_model='gpt-5-nano', error=None, evaluation_cost=0.0008506000000000001, verbose_logs='Statements:\n[\n    "Banana"\n] \n \nVerdicts:\n[\n    {\n        "verdict": "no",\n        "reason": "The statement \'Banana\' is unrelated to who introduced the GPT model."\n    }\n]')], conversational=False, multimodal=False, input='Who introduced the GPT Model?', actual_output='Banana', expected_output='Open AI', context=None, retrieval_context=None, turns=None, additional_metadata=None), TestResult(name='test_case_2', success=True, metrics_data=[MetricData(name='Answer Relevancy', threshold=0.5, success=True, score=1.0, reason='The score is 1.00 because there were no irrelevant statements in the output, so it cannot be higher due to extraneous content; the current score reflects clean relevance, and you can now provide the actual answer to the question.', strict_mode=False, evaluation_model='gpt-5-nano', error=None, evaluation_cost=0.0008724000000000001, verbose_logs='Statements:\n[\n    "Joe Biden"\n] \n \nVerdicts:\n[\n    {\n        "verdict": "yes",\n        "reason": null\n    }\n]')], conversational=False, multimodal=False, input='Who is the current president of the United States of America?', actual_output='Joe Biden', expected_output='Joe Biden', context=None, retrieval_context=None, turns=None, additional_metadata=None), TestResult(name='test_case_1', success=True, metrics_data=[MetricData(name='Answer Relevancy', threshold=0.5, success=True, score=1.0, reason='No irrelevant statements detected in the actual output, so the score cannot be raised due to irrelevance; the current 1.00 reflects a baseline evaluation with no penalties for irrelevance. Great job staying on topic—keep it up!', strict_mode=False, evaluation_model='gpt-5-nano', error=None, evaluation_cost=0.0012106, verbose_logs='Statements:\n[\n    "Anthropic"\n] \n \nVerdicts:\n[\n    {\n        "verdict": "yes",\n        "reason": null\n    }\n]')], conversational=False, multimodal=False, input='Who introduced the GPT Model?', actual_output='Anthropic', expected_output='Open AI', context=None, retrieval_context=None, turns=None, additional_metadata=None), TestResult(name='test_case_0', success=True, metrics_data=[MetricData(name='Answer Relevancy', threshold=0.5, success=True, score=1.0, reason='There are no irrelevant statements in the actual output, so the score isn’t higher due to irrelevancies. Nice and focused—now simply provide the direct answer to the question.', strict_mode=False, evaluation_model='gpt-5-nano', error=None, evaluation_cost=0.0025020500000000005, verbose_logs='Statements:\n[\n    "Joe Biden."\n] \n \nVerdicts:\n[\n    {\n        "verdict": "yes",\n        "reason": "invalid JSON, too long"\n    }\n]')], conversational=False, multimodal=False, input='Who is the current president of the United States of America?', actual_output='Joe Biden', expected_output='Joe Biden', context=None, retrieval_context=None, turns=None, additional_metadata=None)], confident_link='https://app.confident-ai.com/project/cmn70qogs003ilf1enonmdsks/test-runs/cmn7jm4g600hlml1em314mzvx/regression-testing', test_run_id='cmn7jm4g600hlml1em314mzvx')

# %% [markdown]
# ### Using Local LLM for Evaluation

# %%
# !deepeval set-ollama --model gpt-oss:20b --save=dotenv:./../.env
# Out:
# No changes to save in ..\.env.
# 🙌 Congratulations! You're now using a local Ollama model `gpt-oss:20b` for all
# evals that require an LLM.

# %%
from deepeval.test_case import LLMTestCase
from deepeval.metrics import AnswerRelevancyMetric
from deepeval.evaluate import evaluate

answer_relevancy_metric2 = AnswerRelevancyMetric()
print(type(answer_relevancy_metric2.model))
print(answer_relevancy_metric2.evaluation_model)

test_case1 = LLMTestCase(
  input="Who is the current president of the United States of America?",
  actual_output="Joe Biden",
  retrieval_context=["Joe Biden serves as the current president of America."]
)

test_case2 = LLMTestCase(
  input="Who built the Claude Models?",
  actual_output="OpenAI",
  expected_output= "Claude Anthrophic",
  retrieval_context=["Claude Anthrophic built the GPT models."]
)

evaluate(test_cases=[test_case1, test_case2], metrics=[answer_relevancy_metric2])
# Out:
# <class 'deepeval.models.llms.local_model.LocalModel'>
# gpt-oss:20b (Local Model)
# ✨ You're running DeepEval's latest Answer Relevancy Metric! (using gpt-oss:20b (Local Model), strict=False,
# async_mode=True)...
# c:\Users\Navoki\PythonProjects\evluating_agent\.venv\Lib\site-packages\rich\live.py:260: UserWarning: install
# "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[5], line 22
#       9 test_case1 = LLMTestCase(
#      10   input="Who is the current president of the United States of America?",
#      11   actual_output="Joe Biden",
#      12   retrieval_context=["Joe Biden serves as the current president of America."]
#      13 )
#      15 test_case2 = LLMTestCase(
#      16   input="Who built the Claude Models?",
#      17   actual_output="OpenAI",
#      18   expected_output= "Claude Anthrophic",
#      19   retrieval_context=["Claude Anthrophic built the GPT models."]
#      20 )
# ---> 22 evaluate(test_cases=[test_case1, test_case2], metrics=[answer_relevancy_metric2])
#
# File c:\Users\Navoki\PythonProjects\evluating_agent\.venv\Lib\site-packages\deepeval\evaluate\evaluate.py:230, in evaluate(test_cases, metrics, metric_collection, hyperparameters, identifier, _skip_reset, async_config, display_config, cache_config, error_config)
#     228 if async_config.run_async:
#     229     loop = get_or_create_event_loop()
# --> 230     test_results = loop.run_until_complete(
#     231         a_execute_test_cases(
#     232             test_cases,
#     233             metrics,
#     234             identifier=identifier,
#     235             error_config=error_config,
#     236             display_config=display_config,
#     237             cache_config=cache_config,
#     238             async_config=async_config,
#     239         )
#     240     )
#     241 else:
#     242     test_results = execute_test_cases(
#     243         test_cases,
#     244         metrics,
#    (...)    248         cache_config=cache_config,
#     249     )
#
# File c:\Users\Navoki\PythonProjects\evluating_agent\.venv\Lib\site-packages\nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\asyncio\futures.py:199, in Future.result(self)
#     197 self.__log_traceback = False
#     198 if self._exception is not None:
# --> 199     raise self._exception.with_traceback(self._exception_tb)
#     200 return self._result
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\asyncio\tasks.py:306, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     304         result = coro.send(None)
#     305     else:
# --> 306         result = coro.throw(exc)
#     307 except StopIteration as exc:
#     308     if self._must_cancel:
#     309         # Task is cancelled right before coro stops.
#
# File c:\Users\Navoki\PythonProjects\evluating_agent\.venv\Lib\site-packages\deepeval\evaluate\execute.py:678, in a_execute_test_cases(test_cases, metrics, error_config, display_config, cache_config, async_config, identifier, test_run_manager, _use_bar_indicator, _is_assert_test)
#     675         await asyncio.sleep(async_config.throttle_value)
#     677 try:
# --> 678     await asyncio.wait_for(
#     679         asyncio.gather(*tasks),
#     680         timeout=get_gather_timeout(),
#     681     )
#     682 except (asyncio.TimeoutError, TimeoutError) as e:
#     683     for t in tasks:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\asyncio\tasks.py:507, in wait_for(fut, timeout)
#     504         raise TimeoutError from exc
#     506 async with timeouts.timeout(timeout):
# --> 507     return await fut
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\asyncio\tasks.py:375, in Task.__wakeup(self, future)
#     373 def __wakeup(self, future):
#     374     try:
# --> 375         future.result()
#     376     except BaseException as exc:
#     377         # This may also be a cancellation.
#     378         self.__step(exc)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\asyncio\tasks.py:306, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     304         result = coro.send(None)
#     305     else:
# --> 306         result = coro.throw(exc)
#     307 except StopIteration as exc:
#     308     if self._must_cancel:
#     309         # Task is cancelled right before coro stops.
#
# File c:\Users\Navoki\PythonProjects\evluating_agent\.venv\Lib\site-packages\deepeval\evaluate\execute.py:581, in a_execute_test_cases.<locals>.execute_with_semaphore(func, *args, **kwargs)
#     579 async def execute_with_semaphore(func: Callable, *args, **kwargs):
#     580     async with semaphore:
# --> 581         return await _await_with_outer_deadline(
#     582             func, *args, timeout=get_per_task_timeout_seconds(), **kwargs
#     583         )
#
# File c:\Users\Navoki\PythonProjects\evluating_agent\.venv\Lib\site-packages\deepeval\evaluate\execute.py:300, in _await_with_outer_deadline(obj, timeout, *args, **kwargs)
#     297     if get_settings().DEEPEVAL_DISABLE_TIMEOUTS:
#     298         return await coro
# --> 300     return await asyncio.wait_for(coro, timeout=timeout)
#     301 finally:
#     302     reset_outer_deadline(token)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\asyncio\tasks.py:507, in wait_for(fut, timeout)
#     504         raise TimeoutError from exc
#     506 async with timeouts.timeout(timeout):
# --> 507     return await fut
#
# File c:\Users\Navoki\PythonProjects\evluating_agent\.venv\Lib\site-packages\deepeval\evaluate\execute.py:807, in _a_execute_llm_test_cases(metrics, test_case, test_run_manager, test_results, count, test_run, ignore_errors, skip_on_missing_params, use_cache, show_indicator, _use_bar_indicator, _is_assert_test, progress, pbar_id)
#     804     new_cached_test_case: CachedTestCase = CachedTestCase()
#     805     test_start_time = time.perf_counter()
# --> 807     await measure_metrics_with_indicator(
#     808         metrics=metrics,
#     809         test_case=test_case,
#     810         cached_test_case=cached_test_case,
#     811         skip_on_missing_params=skip_on_missing_params,
#     812         ignore_errors=ignore_errors,
#     813         show_indicator=show_metrics_indicator,
#     814         pbar_eval_id=pbar_test_case_id,
#     815         progress=progress,
#     816     )
#     817 except asyncio.CancelledError:
#     818     if get_settings().DEEPEVAL_DISABLE_TIMEOUTS:
#
# File c:\Users\Navoki\PythonProjects\evluating_agent\.venv\Lib\site-packages\deepeval\metrics\indicator.py:238, in measure_metrics_with_indicator(metrics, test_case, cached_test_case, ignore_errors, skip_on_missing_params, show_indicator, progress, pbar_eval_id, _in_component)
#     225     else:
#     226         tasks.append(
#     227             safe_a_measure(
#     228                 metric,
#    (...)    235             )
#     236         )
# --> 238 await asyncio.gather(*tasks)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\asyncio\tasks.py:375, in Task.__wakeup(self, future)
#     373 def __wakeup(self, future):
#     374     try:
# --> 375         future.result()
#     376     except BaseException as exc:
#     377         # This may also be a cancellation.
#     378         self.__step(exc)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\asyncio\tasks.py:304, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     300 try:
#     301     if exc is None:
#     302         # We use the `send` method directly, because coroutines
#     303         # don't have `__iter__` and `__next__` methods.
# --> 304         result = coro.send(None)
#     305     else:
#     306         result = coro.throw(exc)
#
# File c:\Users\Navoki\PythonProjects\evluating_agent\.venv\Lib\site-packages\deepeval\metrics\indicator.py:251, in safe_a_measure(metric, tc, ignore_errors, skip_on_missing_params, progress, pbar_eval_id, _in_component)
#     241 async def safe_a_measure(
#     242     metric: Union[BaseMetric, BaseConversationalMetric],
#     243     tc: Union[LLMTestCase, LLMTestCase, ConversationalTestCase],
#    (...)    248     _in_component: bool = False,
#     249 ):
#     250     try:
# --> 251         await metric.a_measure(
#     252             tc,
#     253             _show_indicator=False,
#     254             _in_component=_in_component,
#     255             _log_metric_to_confident=False,
#     256         )
#     257         update_pbar(progress, pbar_eval_id)
#     259     except asyncio.CancelledError:
#
# File c:\Users\Navoki\PythonProjects\evluating_agent\.venv\Lib\site-packages\deepeval\metrics\answer_relevancy\answer_relevancy.py:143, in AnswerRelevancyMetric.a_measure(self, test_case, _show_indicator, _in_component, _log_metric_to_confident)
#     140 input = test_case.input
#     141 actual_output = test_case.actual_output
# --> 143 self.statements: List[str] = await self._a_generate_statements(
#     144     actual_output, test_case.multimodal
#     145 )
#     146 self.verdicts: List[AnswerRelevancyVerdict] = (
#     147     await self._a_generate_verdicts(input, test_case.multimodal)
#     148 )
#     149 self.score = self._calculate_score()
#
# File c:\Users\Navoki\PythonProjects\evluating_agent\.venv\Lib\site-packages\deepeval\metrics\answer_relevancy\answer_relevancy.py:284, in AnswerRelevancyMetric._a_generate_statements(self, actual_output, multimodal)
#     275 async def _a_generate_statements(
#     276     self,
#     277     actual_output: str,
#     278     multimodal: bool,
#     279 ) -> List[str]:
#     280     prompt = self.evaluation_template.generate_statements(
#     281         actual_output=actual_output, multimodal=multimodal
#     282     )
# --> 284     return await a_generate_with_schema_and_extract(
#     285         metric=self,
#     286         prompt=prompt,
#     287         schema_cls=Statements,
#     288         extract_schema=lambda s: s.statements
#     289         + [ele for ele in actual_output if isinstance(ele, MLLMImage)],
#     290         extract_json=lambda d: d["statements"]
#     291         + [ele for ele in actual_output if isinstance(ele, MLLMImage)],
#     292     )
#
# File c:\Users\Navoki\PythonProjects\evluating_agent\.venv\Lib\site-packages\deepeval\metrics\utils.py:457, in a_generate_with_schema_and_extract(metric, prompt, schema_cls, extract_schema, extract_json)
#     448 async def a_generate_with_schema_and_extract(
#     449     metric: Union[BaseMetric, BaseArenaMetric, BaseConversationalMetric],
#     450     prompt: Any,
#    (...)    454     extract_json: Callable[[Dict[str, Any]], ReturnType],
#     455 ) -> ReturnType:
#     456     if metric.using_native_model:
# --> 457         result, cost = await metric.model.a_generate_with_schema(
#     458             prompt, schema=schema_cls
#     459         )
#     460         metric._accrue_cost(cost)
#     461     else:
#
# File c:\Users\Navoki\PythonProjects\evluating_agent\.venv\Lib\site-packages\deepeval\models\base_model.py:118, in DeepEvalBaseLLM.a_generate_with_schema(self, schema, *args, **kwargs)
#     116 if schema is not None:
#     117     try:
# --> 118         return await self.a_generate(*args, schema=schema, **kwargs)
#     119     except TypeError:
#     120         pass
#
# File c:\Users\Navoki\PythonProjects\evluating_agent\.venv\Lib\site-packages\tenacity\asyncio\__init__.py:193, in AsyncRetrying.wraps.<locals>.async_wrapped(*args, **kwargs)
#     191 copy = self.copy()
#     192 async_wrapped.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 193 return await copy(fn, *args, **kwargs)
#
# File c:\Users\Navoki\PythonProjects\evluating_agent\.venv\Lib\site-packages\tenacity\asyncio\__init__.py:112, in AsyncRetrying.__call__(self, fn, *args, **kwargs)
#     110 is_async = _utils.is_coroutine_callable(fn)
#     111 while True:
# --> 112     do = await self.iter(retry_state=retry_state)
#     113     if isinstance(do, DoAttempt):
#     114         try:
#
# File c:\Users\Navoki\PythonProjects\evluating_agent\.venv\Lib\site-packages\tenacity\asyncio\__init__.py:157, in AsyncRetrying.iter(self, retry_state)
#     155 result = None
#     156 for action in self.iter_state.actions:
# --> 157     result = await action(retry_state)
#     158 return result
#
# File c:\Users\Navoki\PythonProjects\evluating_agent\.venv\Lib\site-packages\tenacity\_utils.py:111, in wrap_to_async_func.<locals>.inner(*args, **kwargs)
#     110 async def inner(*args: typing.Any, **kwargs: typing.Any) -> typing.Any:
# --> 111     return call(*args, **kwargs)
#
# File c:\Users\Navoki\PythonProjects\evluating_agent\.venv\Lib\site-packages\tenacity\__init__.py:393, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     391 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     392     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 393         self._add_action_func(lambda rs: rs.outcome.result())
#     394         return
#     396     if self.after is not None:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception is not None:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\Navoki\PythonProjects\evluating_agent\.venv\Lib\site-packages\tenacity\asyncio\__init__.py:116, in AsyncRetrying.__call__(self, fn, *args, **kwargs)
#     114 try:
#     115     if is_async:
# --> 116         result = await fn(*args, **kwargs)
#     117     else:
#     118         result = fn(*args, **kwargs)
#
# File c:\Users\Navoki\PythonProjects\evluating_agent\.venv\Lib\site-packages\deepeval\models\retry_policy.py:658, in create_retry_decorator.<locals>._decorator.<locals>.attempt(*args, **kwargs)
#     656 if per_attempt_timeout > 0:
#     657     try:
# --> 658         return await asyncio.wait_for(coro, per_attempt_timeout)
#     659     except (asyncio.TimeoutError, TimeoutError) as e:
#     660         if (
#     661             logger.isEnabledFor(logging.DEBUG)
#     662             and get_settings().DEEPEVAL_VERBOSE_MODE is True
#     663         ):
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\asyncio\tasks.py:507, in wait_for(fut, timeout)
#     504         raise TimeoutError from exc
#     506 async with timeouts.timeout(timeout):
# --> 507     return await fut
#
# File c:\Users\Navoki\PythonProjects\evluating_agent\.venv\Lib\site-packages\deepeval\models\llms\local_model.py:125, in LocalModel.a_generate(self, prompt, schema)
#     122     content = prompt
#     124 client = self.load_model(async_mode=True)
# --> 125 response: ChatCompletion = await client.chat.completions.create(
#     126     model=self.name,
#     127     messages=[{"role": "user", "content": content}],
#     128     temperature=self.temperature,
#     129     **self.generation_kwargs,
#     130 )
#     131 res_content = response.choices[0].message.content
#     133 if schema:
#
# File c:\Users\Navoki\PythonProjects\evluating_agent\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:2714, in AsyncCompletions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    2667 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    2668 async def create(
#    2669     self,
#    (...)   2711     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    2712 ) -> ChatCompletion | AsyncStream[ChatCompletionChunk]:
#    2713     validate_response_format(response_format)
# -> 2714     return await self._post(
#    2715         "/chat/completions",
#    2716         body=await async_maybe_transform(
#    2717             {
#    2718                 "messages": messages,
#    2719                 "model": model,
#    2720                 "audio": audio,
#    2721                 "frequency_penalty": frequency_penalty,
#    2722                 "function_call": function_call,
#    2723                 "functions": functions,
#    2724                 "logit_bias": logit_bias,
#    2725                 "logprobs": logprobs,
#    2726                 "max_completion_tokens": max_completion_tokens,
#    2727                 "max_tokens": max_tokens,
#    2728                 "metadata": metadata,
#    2729                 "modalities": modalities,
#    2730                 "n": n,
#    2731                 "parallel_tool_calls": parallel_tool_calls,
#    2732                 "prediction": prediction,
#    2733                 "presence_penalty": presence_penalty,
#    2734                 "prompt_cache_key": prompt_cache_key,
#    2735                 "prompt_cache_retention": prompt_cache_retention,
#    2736                 "reasoning_effort": reasoning_effort,
#    2737                 "response_format": response_format,
#    2738                 "safety_identifier": safety_identifier,
#    2739                 "seed": seed,
#    2740                 "service_tier": service_tier,
#    2741                 "stop": stop,
#    2742                 "store": store,
#    2743                 "stream": stream,
#    2744                 "stream_options": stream_options,
#    2745                 "temperature": temperature,
#    2746                 "tool_choice": tool_choice,
#    2747                 "tools": tools,
#    2748                 "top_logprobs": top_logprobs,
#    2749                 "top_p": top_p,
#    2750                 "user": user,
#    2751                 "verbosity": verbosity,
#    2752                 "web_search_options": web_search_options,
#    2753             },
#    2754             completion_create_params.CompletionCreateParamsStreaming
#    2755             if stream
#    2756             else completion_create_params.CompletionCreateParamsNonStreaming,
#    2757         ),
#    2758         options=make_request_options(
#    2759             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    2760         ),
#    2761         cast_to=ChatCompletion,
#    2762         stream=stream or False,
#    2763         stream_cls=AsyncStream[ChatCompletionChunk],
#    2764     )
#
# File c:\Users\Navoki\PythonProjects\evluating_agent\.venv\Lib\site-packages\openai\_base_client.py:1884, in AsyncAPIClient.post(self, path, cast_to, body, content, files, options, stream, stream_cls)
#    1875     warnings.warn(
#    1876         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1877         "Please pass raw bytes via the `content` parameter instead.",
#    1878         DeprecationWarning,
#    1879         stacklevel=2,
#    1880     )
#    1881 opts = FinalRequestOptions.construct(
#    1882     method="post", url=path, json_data=body, content=content, files=await async_to_httpx_files(files), **options
#    1883 )
# -> 1884 return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File c:\Users\Navoki\PythonProjects\evluating_agent\.venv\Lib\site-packages\openai\_base_client.py:1669, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1666             await err.response.aread()
#    1668         log.debug("Re-raising status error")
# -> 1669         raise self._make_status_error_from_response(err.response) from None
#    1671     break
#    1673 assert response is not None, "could not resolve response (should never happen)"
#
# NotFoundError: 404 page not found
